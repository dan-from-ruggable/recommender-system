# %% [markdown]
# # Bundling Analysis

# %%
# libraries
library(tidyverse)
library(arules)
library(arulesViz)
library(RPostgreSQL)
library(tsibble)
library(gridExtra)
library(clipr)
library(stringr)
library(config)
library(googlesheets4)
library(jsonlite)

# setting wd
if ( grepl("bundles", getwd(), fixed = TRUE) ) {
    print("current working directory is fine")
} else {
    setwd("./projects/bundles")
    print("changed working directory")
}
# Out:
# [1] "current working directory is fine"

# %%
# load functions
source("bundle-functions.R")

# %% [markdown]
# ### Get Transactions

# %%
# get credentials
dw <- config::get(file="./redshift_credentials.yml")

# %%
options(warn=-1)
# connecting to dw
con <- DBI::dbConnect(RPostgreSQL::PostgreSQL(),
                      dbname = dw$dbname,
                      host = dw$host,
                      port = dw$port,
                      user = dw$user,
                      password = dw$password)

# %%
# Returns string without leading or trailing white space
trim <- function (x) gsub("^\\s+|\\s+$", "", x)

# %%
# read query from sql file and execute
#query_1 <- getSQL("sql/data_pull__purchases.sql") 
#df_purchases <- dbGetQuery(con, query_1) %>% as_tibble()

#query_2 <- getSQL("sql/data_pull__purchases_same_size_by_size.sql") 
#df_purchases_same_size_by_size <- dbGetQuery(con, query_2) %>% as_tibble()

query_3 <- getSQL("sql/data_pull__purchases_same_size_overall.sql") 
df_purchases_same_size_overall <- dbGetQuery(con, query_3) %>% as_tibble()

query_4 <- getSQL("sql/data_pull__top-selling-designs.sql")
df_top_designs <- dbGetQuery(con, query_4) %>% as_tibble()

query_5 <- getSQL("sql/data_pull__rug_details.sql") 
df_rug_details <- dbGetQuery(con, query_5) %>% as_tibble()

options(warn=0)

# %%
df_rug_details <- df_rug_details %>% mutate(url = str_remove_all(url,"-two"))

# %%
df_purchases_same_size_overall <- df_purchases_same_size_overall %>% mutate(products_purchased = trim(products_purchased))

# %%
options(warn=-1)
#purchase_transactions <- makeTransaction(df_purchases)
#samesize_bysize_purchase_transactions <- makeTransaction(df_purchases_same_size_by_size)
samesize_overall_purchase_transactions <- makeTransaction(df_purchases_same_size_overall)
options(warn=0)

# %%
num_top_rugs <- 200

# %%
options(warn=-1)
df_reco <- tibble(rug_name = character(),
                  reco_rug = character(),
                  confidence = numeric())
for (i in head(df_top_designs$rug_name,num_top_rugs)) {
    select_rug_rules <- apriori(samesize_overall_purchase_transactions, parameter = list(supp=0.00001, conf=0.0001),appearance = list(lhs=i,default="rhs"))
    df <- as(subset(select_rug_rules,lift > 1.2), "data.frame")
    df_reco <- df_reco %>% add_row(rug_name = labels(lhs(subset(select_rug_rules,lift > 1.2))),
                                   reco_rug = labels(rhs(subset(select_rug_rules,lift > 1.2))),
                                   confidence = df$confidence)
}

df_reco <- df_reco %>% mutate(rug_name = str_remove_all(rug_name,"[{}]"),
                              reco_rug = str_remove_all(reco_rug,"[{}]"))
# Out:
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.06s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1302 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1209 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1185 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.04s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1211 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.04s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1259 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.04s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1219 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.04s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1169 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1068 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.04s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1241 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.04s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1230 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.04s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1087 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1110 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1128 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.04s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [994 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.04s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1131 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.04s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1154 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1113 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1179 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1021 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1060 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1049 rule(s)] done [0.00s].
# creating S4 object  ... done [0.03s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1034 rule(s)] done [0.00s].
# creating S4 object  ... done [0.03s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1165 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1131 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1071 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1070 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1065 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1138 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [976 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1105 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1025 rule(s)] done [0.00s].
# creating S4 object  ... done [0.03s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1060 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1110 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1036 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [996 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1049 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1098 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.06s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1204 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.06s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1095 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.04s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1011 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1070 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1050 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [954 rule(s)] done [0.00s].
# creating S4 object  ... done [0.03s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1114 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1049 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [979 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [977 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.04s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1107 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1014 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1084 rule(s)] done [0.00s].
# creating S4 object  ... done [0.03s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1011 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.07s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [964 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.09s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1048 rule(s)] done [0.00s].
# creating S4 object  ... done [0.05s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [923 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.04s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1007 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.04s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1036 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.04s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1100 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1074 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [991 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.04s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1075 rule(s)] done [0.00s].
# creating S4 object  ... done [0.03s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.06s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.06s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1033 rule(s)] done [0.00s].
# creating S4 object  ... done [0.03s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.06s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1050 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.06s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [991 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.06s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1028 rule(s)] done [0.00s].
# creating S4 object  ... done [0.03s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.06s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.06s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1029 rule(s)] done [0.00s].
# creating S4 object  ... done [0.03s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.07s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.06s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [1064 rule(s)] done [0.00s].
# creating S4 object  ... done [0.03s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.06s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.06s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [981 rule(s)] done [0.00s].
# creating S4 object  ... done [0.04s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# ...
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [890 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.06s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [807 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [936 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [899 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [870 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [899 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [873 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [911 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [928 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [868 rule(s)] done [0.00s].
# creating S4 object  ... done [0.03s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.06s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [903 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [920 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [883 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [909 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [889 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [912 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [944 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.04s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [856 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [883 rule(s)] done [0.00s].
# creating S4 object  ... done [0.03s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.06s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [865 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [857 rule(s)] done [0.00s].
# creating S4 object  ... done [0.03s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.06s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.06s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [876 rule(s)] done [0.00s].
# creating S4 object  ... done [0.03s].
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#       1e-04    0.1    1 none FALSE            TRUE       5   1e-05      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[1 item(s)] done [0.00s].
# set transactions ...[790 item(s), 179283 transaction(s)] done [0.05s].
# sorting and recoding items ... [788 item(s)] done [0.00s].
# creating transaction tree ... done [0.05s].
# checking subsets of size 1 2 done [0.00s].
# writing ... [918 rule(s)] done [0.00s].
# creating S4 object  ... done [0.02s].

# %%
num_recos <- 4

# %%
df_json <- df_reco %>% 
    inner_join(df_rug_details, by = c("reco_rug" = "rug_name")) %>%
    group_by(rug_name) %>%
    mutate(reco_rank = row_number(desc(confidence))) %>%
    filter(reco_rank <=num_recos) %>%
    select(rug_name, reco_rank, reco_rug, image__src, url) %>%
    arrange(rug_name, reco_rank) %>%
    pivot_wider(names_from = reco_rank, values_from = c(reco_rug, image__src, url)) %>%
    relocate(RugName = rug_name,
           Reco_RugName_1 = reco_rug_1,
           Reco_Image_1 = image__src_1,
           Reco_URL_1 = url_1,
           Reco_RugName_2 = reco_rug_2,
           Reco_Image_2 = image__src_2,
           Reco_URL_2 = url_2,
           Reco_RugName_3 = reco_rug_3,
           Reco_Image_3 = image__src_3,
           Reco_URL_3 = url_3,
           Reco_RugName_4 = reco_rug_4,
           Reco_Image_4 = image__src_4,
           Reco_URL_4 = url_4
          )

# %%
jsonData <- toJSON(x = df_json, dataframe = 'rows', pretty = T)

# %%
write(jsonData, "json-outputs/best-sellers-recommended-rugs-v20210806.json")

# %%
jsonData
# Out:
# [
#   {
#     "RugName": "Absida Rainbow Rug",
#     "Reco_RugName_1": "Absida Teal Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/absida-teal-A-RC-MA003-57-V2.jpg?v=1610741355",
#     "Reco_URL_1": "https://ruggable.com/products/absida-teal-rug?size=5x7",
#     "Reco_RugName_2": "Metro Multicolor Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/metro-multicolor-A-RC-0735-57-V2.jpg?v=1612558753",
#     "Reco_URL_2": "https://ruggable.com/products/metro-multicolor-rug?size=5x7",
#     "Reco_RugName_3": "Floral Medallion Multicolor Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/floral-medallion-multicolor-A-RC-0296-57.jpg?v=1592350170",
#     "Reco_URL_3": "https://ruggable.com/products/floral-medallion-multicolor?size=5x7",
#     "Reco_RugName_4": "Gradasi Teal Quartz Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/gradasi-teal-quartz-A-RC-MA006-57-V2.jpg?v=1612388811",
#     "Reco_URL_4": "https://ruggable.com/products/gradasi-teal-quartz-rug?size=5x7"
#   },
#   {
#     "RugName": "Absida Teal Rug",
#     "Reco_RugName_1": "Absida Rainbow Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products
rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/festive-garland-holiday-shortbread-A-RC-HH004-57.jpg?v=1599666322",
#     "Reco_URL_4": "https://ruggable.com/products/festive-garland-holiday-shortbread-rug?size=5x7"
#   },
#   {
#     "RugName": "Camellia Jade Rug",
#     "Reco_RugName_1": "Camellia Midnight Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/camellia-midnight-A-RC-0599-57-V2.jpg?v=1610994736",
#     "Reco_URL_1": "https://ruggable.com/products/camellia-midnight-rug?size=5x7",
#     "Reco_RugName_2": "Watercolor Floral Coral Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/watercolor-floral-coral-A-RC-0425-57.jpg?v=1593206802",
#     "Reco_URL_2": "https://ruggable.com/products/watercolor-floral-coral?size=5x7",
#     "Reco_RugName_3": "Terali Slate Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/terali-slate-A-RC-BS019-57-V2.jpg?v=1612811137",
#     "Reco_URL_3": "https://ruggable.com/products/terali-slate-rug?size=5x7",
#     "Reco_RugName_4": "Floral Medallion Yellow Grey Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/floral-medallion-yellow-grey-A-RC-0379-57.jpg?v=1608823469",
#     "Reco_URL_4": "https://ruggable.com/products/floral-medallion-yellow-grey?size=5x7"
#   },
#   {
#     "RugName": "Camellia Midnight Rug",
#     "Reco_RugName_1": "Camellia Jade Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/camellia-jade-A-RC-0597-57-V2.jpg?v=1622737596",
#     "Reco_URL_1": "https://ruggable.com/products/camellia-jade-rug?size=5x7",
#     "Reco_RugName_2": "Watercolor Floral Navy Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/watercolor-floral-navy-A-RC-0426-57-V2.jpg?v=1612814511",
#     "Reco_URL_2": "https://ruggable.com/products/watercolor-floral-navy?size=5x7",
#     "Reco_RugName_3": "Watercolor Floral Coral Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/watercolor-floral-coral-A-RC-0425-57.jpg?v=1593206802",
#     "Reco_URL_3": "https://ruggable.com/products/watercolor-floral-coral?size=5x7",
#     "Reco_RugName_4": "Delphina Navy Blue Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/delphina-navy-blue-A-RC-MT029-57.jpg?v=1583372923",
#     "Reco_URL_4": "https://ruggable.com/products/delphina-navy-blue-rug?size=5x7"
#   },
#   {
#     "RugName": "Casablanca Blue Green Rug",
#     "Reco_RugName_1": "Camellia Jade Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/camellia-jade-A-RC-0597-57-V2.jpg?v=1622737596",
#     "Reco_URL_1": "https://ruggable.com/products/camellia-jade-rug?size=5x7",
#     "Reco_RugName_2": "Terali Slate Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/terali-slate-A-RC-BS019-57-V2.jpg?v=1612811137",
#     "Reco_URL_2": "https://ruggable.com/products/terali-slate-rug?size=5x7",
#     "Reco_RugName_3": "Coastal Linear Stripe Slate Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/coastal-linear-stripe-slate-A-RC-0324-57.jpg?v=1603994873",
#     "Reco_URL_3": "https://ruggable.com/products/coastal-linear-stripe-slate?size=5x7",
#     "Reco_RugName_4": "Hesperia Teal Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/hesperia-teal-A-RC-0739-57-V2.jpg?v=1612399207",
#     "Reco_URL_4": "https://ruggable.com/products/hesperia-teal-rug?size=5x7"
#   },
#   {
#     "RugName": "Celestine Coral Rug",
#     "Reco_RugName_1": "Kamran Coral Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/kamran-coral-A-RC-JB007-57.jpg?v=1594232705",
#     "Reco_URL_1": "https://ruggable.com/products/kamran-coral-rug?size=5x7",
#     "Reco_RugName_2": "Celestine Teal Blue Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/celestine-teal-blue-A-RC-JB005-57.jpg?v=1594232788",
#     "Reco_URL_2": "https://ruggable.com/products/celestine-teal-blue-rug?size=5x7",
#     "Reco_RugName_3": "Kamran Royal Blue Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/kamran-royal-blue-A-RC-JB006-57.jpg?v=1622751679",
#     "Reco_URL_3": "https://ruggable.com/products/kamran-royal-blue-rug?size=5x7",
#     "Reco_RugName_4": "Cambria Ruby Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/cambria-ruby-V2-A-RC-JB012-57_0ae899f3-459a-48e5-a05a-ecb94441e97d.jpg?v=1610743007",
#     "Reco_URL_4": "https://ruggable.com/products/cambria-ruby?size=5x7"
#   },
#   {
#     "RugName": "Celestine Sapphire Rug",
#     "Reco_RugName_1": "Kamran Royal Blue Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/kamran-royal-blue-A-RC-JB006-57.jpg?v=1622751679",
#     "Reco_URL_1": "https://ruggable.com/products/kamran-royal-blue-rug?size=5x7",
#     "Reco_RugName_2": "Celestine Teal Blue Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/celestine-teal-blue-A-RC-JB005-57.jpg?v=1594232788",
#     "Reco_URL_2": "https://ruggable.com/products/celestine-teal-blue-rug?size=5x7",
#     "Reco_RugName_3": "Celestine Coral Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/celestine-coral-A-RC-JB010-57.jpg?v=1622738544",
#     "Reco_URL_3": "https://ruggable.com/products/celestine-coral-rug?size=5x7",
#     "Reco_RugName_4": "Cambria Sapphire Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/cambria-sapphire-V2-A-RC-JB013-57_1f2eafb0-9bed-41e6-9ab3-414866b2296a.jpg?v=1610743158",
#     "Reco_URL_4": "https://ruggable.com/products/cambria-sapphire?size=5x7"
#   },
#   {
#     "RugName": "Celestine Teal Blue Rug",
#     "Reco_RugName_1": "Kamran Coral Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/kamran-coral-A-RC-JB007-57.jpg?v=1594232705",
#     "Reco_URL_1": "https://ruggable.com/products/kamran-coral-rug?size=5x7",
#     "Reco_RugName_2": "Celestine Coral Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/celestine-coral-A-RC-JB010-57.jpg?v=1622738544",
#     "Reco_URL_2": "https://ruggable.com/products/celestine-coral-rug?size=5x7",
#     "Reco_RugName_3": "Kamran Royal Blue Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/kamran-royal-blue-A-RC-JB006-57.jpg?v=1622751679",
#     "Reco_URL_3": "https://ruggable.com/products/kamran-royal-blue-rug?size=5x7",
#     "Reco_RugName_4": "Celestine Sapphire Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/celestine-sapphire-A-RC-JB009-57.jpg?v=1594232829",
#     "Reco_URL_4": "https://ruggable.com/products/celestine-sapphire-rug?size=5x7"
#   },
#   {
#     "RugName": "Chrysanthemum Ash Grey Rug",
#     "Reco_RugName_1": "Floral Medallion Yellow Grey Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/floral-medallion-yellow-grey-A-RC-0379-57.jpg?v=1608823469",
#     "Reco_URL_1": "https://ruggable.com/products/floral-medallion-yellow-grey?size=5x7",
#     "Reco_RugName_2": "Impasto Greyscale Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/impasto-greyscale-A-RC-MO012-57.jpg?v=1579910508",
#     "Reco_URL_2": "https://ruggable.com/products/impasto-greyscale-rug?size=5x7",
#     "Reco_RugName_3": "Watercolor Floral Coral Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/watercolor-floral-coral-A-RC-0425-57.jpg?v=1593206802",
#     "Reco_URL_3": "https://ruggable.com/products/watercolor-floral-coral?size=5x7",
#     "Reco_RugName_4": "Cosmic Marble Grey Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/cosmic-marble-grey-A-RC-0412-57-V2.jpg?v=1611267192",
#     "Reco_URL_4": "https://ruggable.com/products/cosmic-marble-grey?size=5x7"
#   },
#   {
#     "RugName": "Coastal Linear Stripe Slate Rug",
#     "Reco_RugName_1": "Impasto Slate Blue Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/impasto-slate-blue-A-RC-MO011-57.jpg?v=1604071181",
#     "Reco_URL_1": "https://ruggable.com/products/impasto-slate-blue-rug?size=5x7",
#     "Reco_RugName_2": "Starfish Pale Blue Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/starfish-pale-blue-A-RC-0320-57.jpg?v=1604073110",
#     "Reco_URL_2": "https://ruggable.com/products/starfish-pale-blue?size=5x7",
#     "Reco_RugName_3": "Multi Stripe Blue Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/multi-stripe-blue-A-RC-0220-57_f0e10840-97dd-4ddb-b636-ab312c65a0c9.jpg?v=1592350735",
#     "Reco_URL_3": "https://ruggable.com/products/multi-stripe-blue?size=5x7",
#     "Reco_RugName_4": "Meridian Blue Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/meridian-blue-A-RC-0317-57.jpg?v=1592350640",
#     "Reco_URL_4": "https://ruggable.com/products/meridian-blue?size=5x7"
#   },
#   {
#     "RugName": "Corellian Ikat Navy Rug",
#     "Reco_RugName_1": "The Rebellion Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/the-rebellion-A-RC-SW014-57.jpg?v=1596481226",
#     "Reco_URL_1": "https://ruggable.com/products/the-rebellion-star-wars-rug?size=5x7",
#     "Reco_RugName_2": "Corellian Ikat Polychrome Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/corellian-ikat-polychrome-A-RC-SW011-57.jpg?v=1595774987",
#     "Reco_URL_2": "https://ruggable.com/products/corellian-ikat-polychrome-star-wars-rug?size=5x7",
#     "Reco_RugName_3": "Smugglers Geo R2D2 Blue Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/smugglers-geo-r2d2-blue-A-RC-SW007-57.jpg?v=1596235248",
#     "Reco_URL_3": "https://ruggable.com/products/smugglers-geo-r2d2-blue-star-wars-rug?size=5x7",
#     "Reco_RugName_4": "Rogue Squadron Dark Teal Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/rogue-squadron-dark-teal-A-RC-SW016-57.jpg?v=1596218774",
#     "Reco_URL_4": "https://ruggable.com/products/rogue-squadron-dark-teal-star-wars-rug?size=5x7"
#   },
#   {
#     "RugName": "Corellian Ikat Polychrome Rug",
#     "Reco_RugName_1": "The Rebellion Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/the-rebellion-A-RC-SW014-57.jpg?v=1596481226",
#     "Reco_URL_1": "https://ruggable.com/products/the-rebellion-star-wars-rug?size=5x7",
#     "Reco_RugName_2": "Corellian Ikat Navy Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/corellian-ikat-navy-A-RC-SW010-57.jpg?v=1595774679",
#     "Reco_URL_2": "https://ruggable.com/products/corellian-ikat-navy-star-wars-rug?size=5x7",
#     "Reco_RugName_3": "Smugglers Geo R2D2 Blue Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/smugglers-geo-r2d2-blue-A-RC-SW007-57.jpg?v=1596235248",
#     "Reco_URL_3": "https://ruggable.com/products/smugglers-geo-r2d2-blue-star-wars-rug?size=5x7",
#     "Reco_RugName_4": "Dark Side Damask Delft Blue Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/dark-side-damask-delft-blue-A-RC-SW003-57.jpg?v=1596486536",
#     "Reco_URL_4": "https://ruggable.com/products/dark-side-damask-delft-blue-star-wars-rug?size=5x7"
#   },
#   {
#     "RugName": "Cosima Teal Rug",
#     "Reco_RugName_1": "Floral Medallion Multicolor Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/floral-medallion-multicolor-A-RC-0296-57.jpg?v=1592350170",
#     "Reco_URL_1": "https://ruggable.com/products/floral-medallion-multicolor?size=5x7",
#     "Reco_RugName_2": "Kenza Polychrome Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/kenza-polychrome-A-RC-0354-57-V2.jpg?v=1612488460",
#     "Reco_URL_2": "https://ruggable.com/products/kenza-polychrome?size=5x7",
#     "Reco_RugName_3": "Hesperia Teal Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/hesperia-teal-A-RC-0739-57-V2.jpg?v=1612399207",
#     "Reco_URL_3": "https://ruggable.com/products/hesperia-teal-rug?size=5x7",
#     "Reco_RugName_4": "Pina Teal Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/pina-teal-A-RC-TP017-57-V2.jpg?v=1612629630",
#     "Reco_URL_4": "https://ruggable.com/products/pina-teal-rug?size=5x7"
#   },
#   {
#     "RugName": "Crosshatch Light Grey Rug",
#     "Reco_RugName_1": "Prisma Monochrome Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products
rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/dessa-diamond-charcoal-A-RC-MT023-57_24789521-4f83-46bf-a425-82ee9b73f23e.jpg?v=1576632307",
#     "Reco_URL_4": "https://ruggable.com/products/dessa-diamond-charcoal-rug?size=5x7"
#   },
#   {
#     "RugName": "Desert Ivory Blue Rug",
#     "Reco_RugName_1": "Desert Sumac Rug",
# ...
#     "Reco_URL_3": "https://ruggable.com/products/vintage-daisy-bordered-grey?size=5x7",
#     "Reco_RugName_4": "Vintage Daisy Bordered Blue Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/vintage-daisy-bordered-blue-A-RC-RE133-57.jpg?v=1604073800",
#     "Reco_URL_4": "https://ruggable.com/products/vintage-daisy-bordered-blue?size=5x7"
#   },
#   {
#     "RugName": "Vintage Daisy Bordered Tangerine Rug",
#     "Reco_RugName_1": "Celestine Coral Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/celestine-coral-A-RC-JB010-57.jpg?v=1622738544",
#     "Reco_URL_1": "https://ruggable.com/products/celestine-coral-rug?size=5x7",
#     "Reco_RugName_2": "Cambria Ruby Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/cambria-ruby-V2-A-RC-JB012-57_0ae899f3-459a-48e5-a05a-ecb94441e97d.jpg?v=1610743007",
#     "Reco_URL_2": "https://ruggable.com/products/cambria-ruby?size=5x7",
#     "Reco_RugName_3": "Vintage Daisy Bordered Blue Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/vintage-daisy-bordered-blue-A-RC-RE133-57.jpg?v=1604073800",
#     "Reco_URL_3": "https://ruggable.com/products/vintage-daisy-bordered-blue?size=5x7",
#     "Reco_RugName_4": "Suzani Coral Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/suzani-coral-A-RC-0030-57.jpg?v=1604073215",
#     "Reco_URL_4": "https://ruggable.com/products/suzani-coral-rug?size=5x7"
#   },
#   {
#     "RugName": "Vintage Heriz Cerulean Rug",
#     "Reco_RugName_1": "Sima Royal Blue Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/sima-royal-blue-A-RC-0516-57-V2.jpg?v=1612805474",
#     "Reco_URL_1": "https://ruggable.com/products/sima-royal-blue?size=5x7",
#     "Reco_RugName_2": "Hendesi Heriz Sage Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/hendesi-heriz-sage-A-RC-BS005-57-V2.jpg?v=1612399288",
#     "Reco_URL_2": "https://ruggable.com/products/hendesi-heriz-sage-rug?size=5x7",
#     "Reco_RugName_3": "Cambria Sapphire Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/cambria-sapphire-V2-A-RC-JB013-57_1f2eafb0-9bed-41e6-9ab3-414866b2296a.jpg?v=1610743158",
#     "Reco_URL_3": "https://ruggable.com/products/cambria-sapphire?size=5x7",
#     "Reco_RugName_4": "Cambria Ruby Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/cambria-ruby-V2-A-RC-JB012-57_0ae899f3-459a-48e5-a05a-ecb94441e97d.jpg?v=1610743007",
#     "Reco_URL_4": "https://ruggable.com/products/cambria-ruby?size=5x7"
#   },
#   {
#     "RugName": "Vintage Heriz Ivory Blue Rug",
#     "Reco_RugName_1": "Hendesi Heriz Abalone Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/hendesi-heriz-abalone-A-RC-0504-57-V2.jpg?v=1612399037",
#     "Reco_URL_1": "https://ruggable.com/products/hendesi-heriz-abalone-rug?size=5x7",
#     "Reco_RugName_2": "Sima Royal Blue Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/sima-royal-blue-A-RC-0516-57-V2.jpg?v=1612805474",
#     "Reco_URL_2": "https://ruggable.com/products/sima-royal-blue?size=5x7",
#     "Reco_RugName_3": "Vintage Heriz Cerulean Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/vintage-heriz-cerulean-A-RC-0499-57-V2.jpg?v=1612814569",
#     "Reco_URL_3": "https://ruggable.com/products/vintage-heriz-cerulean?size=5x7",
#     "Reco_RugName_4": "Cambria Sapphire Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/cambria-sapphire-V2-A-RC-JB013-57_1f2eafb0-9bed-41e6-9ab3-414866b2296a.jpg?v=1610743158",
#     "Reco_URL_4": "https://ruggable.com/products/cambria-sapphire?size=5x7"
#   },
#   {
#     "RugName": "Watercolor Floral Coral Rug",
#     "Reco_RugName_1": "Camellia Jade Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/camellia-jade-A-RC-0597-57-V2.jpg?v=1622737596",
#     "Reco_URL_1": "https://ruggable.com/products/camellia-jade-rug?size=5x7",
#     "Reco_RugName_2": "Floral Medallion Yellow Grey Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/floral-medallion-yellow-grey-A-RC-0379-57.jpg?v=1608823469",
#     "Reco_URL_2": "https://ruggable.com/products/floral-medallion-yellow-grey?size=5x7",
#     "Reco_RugName_3": "Watercolor Floral Navy Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/watercolor-floral-navy-A-RC-0426-57-V2.jpg?v=1612814511",
#     "Reco_URL_3": "https://ruggable.com/products/watercolor-floral-navy?size=5x7",
#     "Reco_RugName_4": "Frida Floral Natural Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/frida-floral-natural-A-RC-0429-57.jpg?v=1592350256",
#     "Reco_URL_4": "https://ruggable.com/products/frida-floral-natural?size=5x7"
#   },
#   {
#     "RugName": "Watercolor Floral Multicolor Rug",
#     "Reco_RugName_1": "Watercolor Floral Navy Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/watercolor-floral-navy-A-RC-0426-57-V2.jpg?v=1612814511",
#     "Reco_URL_1": "https://ruggable.com/products/watercolor-floral-navy?size=5x7",
#     "Reco_RugName_2": "Watercolor Floral Coral Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/watercolor-floral-coral-A-RC-0425-57.jpg?v=1593206802",
#     "Reco_URL_2": "https://ruggable.com/products/watercolor-floral-coral?size=5x7",
#     "Reco_RugName_3": "Floral Medallion Multicolor Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/floral-medallion-multicolor-A-RC-0296-57.jpg?v=1592350170",
#     "Reco_URL_3": "https://ruggable.com/products/floral-medallion-multicolor?size=5x7",
#     "Reco_RugName_4": "Marble Golden Ivory Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/marble-golden-ivory-A-RC-0487-57-V2.jpg?v=1612558695",
#     "Reco_URL_4": "https://ruggable.com/products/marble-golden-ivory?size=5x7"
#   },
#   {
#     "RugName": "Watercolor Floral Navy Rug",
#     "Reco_RugName_1": "Watercolor Floral Coral Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/watercolor-floral-coral-A-RC-0425-57.jpg?v=1593206802",
#     "Reco_URL_1": "https://ruggable.com/products/watercolor-floral-coral?size=5x7",
#     "Reco_RugName_2": "Watercolor Floral Multicolor Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/watercolor-floral-multi-A-RC-0419-57.jpg?v=1592351469",
#     "Reco_URL_2": "https://ruggable.com/products/watercolor-floral-multicolor?size=5x7",
#     "Reco_RugName_3": "Floral Medallion Multicolor Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/floral-medallion-multicolor-A-RC-0296-57.jpg?v=1592350170",
#     "Reco_URL_3": "https://ruggable.com/products/floral-medallion-multicolor?size=5x7",
#     "Reco_RugName_4": "Camellia Midnight Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/camellia-midnight-A-RC-0599-57-V2.jpg?v=1610994736",
#     "Reco_URL_4": "https://ruggable.com/products/camellia-midnight-rug?size=5x7"
#   },
#   {
#     "RugName": "Watercolor Herringbone Blue Rug",
#     "Reco_RugName_1": "Impasto Slate Blue Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/impasto-slate-blue-A-RC-MO011-57.jpg?v=1604071181",
#     "Reco_URL_1": "https://ruggable.com/products/impasto-slate-blue-rug?size=5x7",
#     "Reco_RugName_2": "Camellia Jade Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/camellia-jade-A-RC-0597-57-V2.jpg?v=1622737596",
#     "Reco_URL_2": "https://ruggable.com/products/camellia-jade-rug?size=5x7",
#     "Reco_RugName_3": "Watercolor Herringbone Grey Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/watercolor-herringbone-grey-A-RC-0529-57-V2.jpg?v=1608822816",
#     "Reco_URL_3": "https://ruggable.com/products/watercolor-herringbone-grey?size=5x7",
#     "Reco_RugName_4": "Serenata Slate Blue Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/serenata-slate-blue-A-RC-0387-57_f54a3b2f-fdc1-494c-89e9-b2cf93d76169.jpg?v=1604072412",
#     "Reco_URL_4": "https://ruggable.com/products/serenata-slate-blue?size=5x7"
#   },
#   {
#     "RugName": "Watercolor Herringbone Cream Rug",
#     "Reco_RugName_1": "Prisma Monochrome Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/prisma-monochrome-A-RC-0540-57-V3.jpg?v=1623809697",
#     "Reco_URL_1": "https://ruggable.com/products/prisma-monochrome?size=5x7",
#     "Reco_RugName_2": "Watercolor Herringbone Grey Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/watercolor-herringbone-grey-A-RC-0529-57-V2.jpg?v=1608822816",
#     "Reco_URL_2": "https://ruggable.com/products/watercolor-herringbone-grey?size=5x7",
#     "Reco_RugName_3": "Camellia Jade Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/camellia-jade-A-RC-0597-57-V2.jpg?v=1622737596",
#     "Reco_URL_3": "https://ruggable.com/products/camellia-jade-rug?size=5x7",
#     "Reco_RugName_4": "Granite Ombre Light Grey Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/granite-ombre-light-grey-A-RC-0411-57-V2.jpg?v=1612388650",
#     "Reco_URL_4": "https://ruggable.com/products/granite-ombre-light-grey?size=5x7"
#   },
#   {
#     "RugName": "Watercolor Herringbone Grey Rug",
#     "Reco_RugName_1": "Herringbone Batik Ash Grey Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/herringbone-batik-ash-grey-A-RC-0407-57-V2.jpg?v=1608821898",
#     "Reco_URL_1": "https://ruggable.com/products/herringbone-batik-ash-grey?size=5x7",
#     "Reco_RugName_2": "Watercolor Herringbone Cream Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/watercolor-herringbone-cream-A-RC-0530-57-V2.jpg?v=1612814626",
#     "Reco_URL_2": "https://ruggable.com/products/watercolor-herringbone-cream?size=5x7",
#     "Reco_RugName_3": "Kavi Mosaic Stone Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/kavi-mosaic-stone-A-RC-0403-57.jpg?v=1623340225",
#     "Reco_URL_3": "https://ruggable.com/products/kavi-mosaic-stone-rug?size=5x7",
#     "Reco_RugName_4": "Impasto Greyscale Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/impasto-greyscale-A-RC-MO012-57.jpg?v=1579910508",
#     "Reco_URL_4": "https://ruggable.com/products/impasto-greyscale-rug?size=5x7"
#   },
#   {
#     "RugName": "Watercolor Waves Sandstone Rug",
#     "Reco_RugName_1": "Linear Striped Multicolor Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/linear-striped-multicolor-A-RC-0246-57.jpg?v=1582579941",
#     "Reco_URL_1": "https://ruggable.com/products/linear-striped-multi?size=5x7",
#     "Reco_RugName_2": "Floral Medallion Multicolor Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/floral-medallion-multicolor-A-RC-0296-57.jpg?v=1592350170",
#     "Reco_URL_2": "https://ruggable.com/products/floral-medallion-multicolor?size=5x7",
#     "Reco_RugName_3": "Watercolor Floral Coral Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/watercolor-floral-coral-A-RC-0425-57.jpg?v=1593206802",
#     "Reco_URL_3": "https://ruggable.com/products/watercolor-floral-coral?size=5x7",
#     "Reco_RugName_4": "Meridian Blue Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/meridian-blue-A-RC-0317-57.jpg?v=1592350640",
#     "Reco_URL_4": "https://ruggable.com/products/meridian-blue?size=5x7"
#   },
#   {
#     "RugName": "Yuma Polychrome Rug",
#     "Reco_RugName_1": "Desert Sumac Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/desert-sumac-A-RC-0693-57.jpg?v=1619496267",
#     "Reco_URL_1": "https://ruggable.com/products/desert-sumac-rug?size=5x7",
#     "Reco_RugName_2": "Saltillo Polychrome Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/saltillo-polychrome-A-RC-0713-57-V2.jpg?v=1612629587",
#     "Reco_URL_2": "https://ruggable.com/products/saltillo-polychrome-rug?size=5x7",
#     "Reco_RugName_3": "Anza Polychrome Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/anza-polychrome-A-RC-0683-57-V2.jpg?v=1610741239",
#     "Reco_URL_3": "https://ruggable.com/products/anza-polychrome-rug?size=5x7",
#     "Reco_RugName_4": "Kilim Batik Multicolor Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/kilim-batik-multicolor-A-RC-0176-57-V2.jpg?v=1612488287",
#     "Reco_URL_4": "https://ruggable.com/products/kilim-batik-multicolor?size=5x7"
#   },
#   {
#     "RugName": "Zareen Oxblood Red Rug",
#     "Reco_RugName_1": "Zareen Scarlet Red Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/zareen-scarlet-red-A-RC-JB001-57.jpg?v=1594232541",
#     "Reco_URL_1": "https://ruggable.com/products/zareen-scarlet-red-rug?size=5x7",
#     "Reco_RugName_2": "Cambria Ruby Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/cambria-ruby-V2-A-RC-JB012-57_0ae899f3-459a-48e5-a05a-ecb94441e97d.jpg?v=1610743007",
#     "Reco_URL_2": "https://ruggable.com/products/cambria-ruby?size=5x7",
#     "Reco_RugName_3": "Damali Black & White Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/damali-black-white-A-RC-MT001-57.jpg?v=1622738960",
#     "Reco_URL_3": "https://ruggable.com/products/damali-black-white-rug?size=5x7",
#     "Reco_RugName_4": "Cambria Sapphire Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/cambria-sapphire-V2-A-RC-JB013-57_1f2eafb0-9bed-41e6-9ab3-414866b2296a.jpg?v=1610743158",
#     "Reco_URL_4": "https://ruggable.com/products/cambria-sapphire?size=5x7"
#   },
#   {
#     "RugName": "Zareen Scarlet Red Rug",
#     "Reco_RugName_1": "Cambria Ruby Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/cambria-ruby-V2-A-RC-JB012-57_0ae899f3-459a-48e5-a05a-ecb94441e97d.jpg?v=1610743007",
#     "Reco_URL_1": "https://ruggable.com/products/cambria-ruby?size=5x7",
#     "Reco_RugName_2": "Verena Dark Wood Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/verena-dark-wood-A-RC-JB004-57_0e3b09e8-4a52-48f1-97e8-b3eb130cec7b.jpg?v=1594233236",
#     "Reco_URL_2": "https://ruggable.com/products/verena-dark-wood-rug?size=5x7",
#     "Reco_RugName_3": "Damali Black & White Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/damali-black-white-A-RC-MT001-57.jpg?v=1622738960",
#     "Reco_URL_3": "https://ruggable.com/products/damali-black-white-rug?size=5x7",
#     "Reco_RugName_4": "Zareen Oxblood Red Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/zareen-oxblood-red-A-RC-MT013-57.jpg?v=1604343835",
#     "Reco_URL_4": "https://ruggable.com/products/zareen-oxblood-red-rug?size=5x7"
#   },
#   {
#     "RugName": "Zareen Steel Blue Rug",
#     "Reco_RugName_1": "Verena Dark Wood Rug",
#     "Reco_Image_1": "https://cdn.shopify.com/s/files/1/1033/0751/products/verena-dark-wood-A-RC-JB004-57_0e3b09e8-4a52-48f1-97e8-b3eb130cec7b.jpg?v=1594233236",
#     "Reco_URL_1": "https://ruggable.com/products/verena-dark-wood-rug?size=5x7",
#     "Reco_RugName_2": "Zareen Scarlet Red Rug",
#     "Reco_Image_2": "https://cdn.shopify.com/s/files/1/1033/0751/products/zareen-scarlet-red-A-RC-JB001-57.jpg?v=1594232541",
#     "Reco_URL_2": "https://ruggable.com/products/zareen-scarlet-red-rug?size=5x7",
#     "Reco_RugName_3": "Cambria Abalone Rug",
#     "Reco_Image_3": "https://cdn.shopify.com/s/files/1/1033/0751/products/cambria-abalone-A-RC-JB011-57.jpg?v=1601415369",
#     "Reco_URL_3": "https://ruggable.com/products/cambria-abalone-rug?size=5x7",
#     "Reco_RugName_4": "Desert Ivory Blue Rug",
#     "Reco_Image_4": "https://cdn.shopify.com/s/files/1/1033/0751/products/desert-ivory-blue-A-RC-0695-57.jpg?v=1619496344",
#     "Reco_URL_4": "https://ruggable.com/products/desert-ivory-blue-rug?size=5x7"
#   }
# ]
